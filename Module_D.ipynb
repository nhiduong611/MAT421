# %% [markdown]
# <a href="https://colab.research.google.com/github/nhiduong611/MAT421/blob/main/Module_D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Space

# %%
# Show vector x is a linear combination of v, u, w

import numpy as np

v = np.array([[0, 3, 2]])
w = np.array([[4, 1, 1]])
u = np.array([[0, -2, 0]])
x = 3*v-2*w+4*u
print(x)
# Out:
# [[-8 -1  4]]

# %% [markdown]
# Orthogonality

# %%
# Define two vectors
v1 = np.array([1, 2, 0])
v2 = np.array([-2, 1, 1])

# Calculate dot product
dot_product = np.dot(v1, v2)

# Check if the dot product is zero (indicating orthogonality)
if dot_product == 0:
    print("The vectors v1 and v2 are orthogonal.")
else:
    print("The vectors v1 and v2 are not orthogonal.")
# Out:
# The vectors v1 and v2 are orthogonal.

# %% [markdown]
# Eigenvalues

# %%
# Define a matrix
A = np.array([[3, 1],
              [1, 3]])

# Compute eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

# Display eigenvalues and eigenvectors
for i in range(len(eigenvalues)):
    print("Eigenvalue:", eigenvalues[i])
    print("Eigenvector:", eigenvectors[:, i])
# Out:
# Eigenvalue: 4.0
# Eigenvector: [0.70710678 0.70710678]
# Eigenvalue: 2.0
# Eigenvector: [-0.70710678  0.70710678]

# %% [markdown]
# Linear regression

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate some sample data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)   # Generate 100 random numbers between 0 and 2
y = 4 + 3 * X + np.random.randn(100, 1)  # Linear relationship with some noise

# Visualize the data
plt.scatter(X, y, color='blue')
plt.title('Sample Data for Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# Perform linear regression
model = LinearRegression()
model.fit(X, y)

# Get the slope (coefficients) and intercept
slope = model.coef_[0][0]
intercept = model.intercept_[0]
print("Slope:", slope)
print("Intercept:", intercept)

# Plot the linear regression line
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
# Out:
# Slope: 2.968467510701019
# Intercept: 4.222151077447231
